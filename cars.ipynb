# %%
import pandas as pd
df = pd.read_csv("usedcars.csv")

# %%
df.head()
# Out:
#    Unnamed: 0          id                                                url  \
# 0      167249  7233579421  https://bgky.craigslist.org/ctd/d/hendersonvil...
# 1        5908  7239041885  https://anchorage.craigslist.org/cto/d/anchora...
# 2       65658  7231444059  https://visalia.craigslist.org/cto/d/fresno-20...
# 3      344616  7230914355  https://scranton.craigslist.org/ctd/d/scranton...
# 4      120298  7227830430  https://columbusga.craigslist.org/ctd/d/dodge-...
#
#                     region                         region_url  price    year  \
# 0            bowling green        https://bgky.craigslist.org  19000  2019.0
# 1       anchorage / mat-su   https://anchorage.craigslist.org  20431  2020.0
# 2           visalia-tulare     https://visalia.craigslist.org   7900  2013.0
# 3  scranton / wilkes-barre    https://scranton.craigslist.org  29990  2017.0
# 4                 columbus  https://columbusga.craigslist.org      0  2018.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    7000 non-null   int64
#  1   id            7000 non-null   int64
#  2   url           7000 non-null   object
#  3   region        7000 non-null   object
#  4   region_url    7000 non-null   object
#  5   price         7000 non-null   int64
#  6   year          6986 non-null   float64
#  7   manufacturer  6718 non-null   object
#  8   model         6934 non-null   object
#  9   condition     4063 non-null   object
#  10  cylinders     4376 non-null   object
#  11  fuel          6945 non-null   object
#  12  odometer      6166 non-null   float64
#  13  title_status  6968 non-null   object
#  14  transmission  6964 non-null   object
#  15  VIN           4157 non-null   object
#  16  drive         4956 non-null   object
#  17  size          2092 non-null   object
# ...

# %%
sorted(list(df[df["manufacturer"].isna() != True]["manufacturer"].unique()))[:3]
# Out:
# ['acura', 'alfa-romeo', 'audi']

# %%
df.sort_values(["price", "odometer"]=, ascending = [False, True])[["manufacturer","model","year","price","odometer"]]
# Out:
#      manufacturer                                              model    year  \
# 4382          NaN                                   Rolls royce dawn  2017.0
# 711          jeep                                     grand cherokee  2019.0
# 2935          NaN                                Lamborghini Huracan  2018.0
# 1092          NaN                                Mclaren 570s spider  2018.0
# 3421          NaN                                Mclaren 570s spider  2018.0
# ...           ...                                                ...     ...
# 6662    chevrolet                                     silverado 1500  2009.0
# 6780        dodge                                               dart  2013.0
# 6869      hyundai  santa fe gls *fr $499 down guaranteed finance awd  2013.0
# 6947        buick                                            enclave  2008.0
# 6997          gmc                                        sierra 1500  2017.0
#
#        price  odometer
# ...

# %%
df["image_url"]
# Out:
# 0       https://images.craigslist.org/00H0H_73RNQQboP1...
# 1       https://images.craigslist.org/00i0i_cv7zpHS5Us...
# 2       https://images.craigslist.org/00n0n_88TYEuTyUC...
# 3       https://images.craigslist.org/00i0i_lWqqcki5Wx...
# 4       https://images.craigslist.org/00o0o_jLA8H4uEZV...
#                               ...
# 6995    https://images.craigslist.org/01111_4F35SI5RmL...
# 6996    https://images.craigslist.org/00T0T_d3ufeRpR6z...
# 6997    https://images.craigslist.org/00505_6FKjuDeWm6...
# 6998    https://images.craigslist.org/01212_ewbtGvwRHq...
# 6999    https://images.craigslist.org/00s0s_fWv3dsit3K...
# Name: image_url, Length: 7000, dtype: object
